# %%
import urllib.robotparser

rp = urllib.robotparser.RobotFileParser()
rp.set_url("https://www.etsy.com/robots.txt")
rp.read()
rp.crawl_delay("*")

test_crawl_url="https://play.google.com/store/apps/details?id=com.wildnotion.poetscorner"

can_crawl_listings = rp.can_fetch("*", test_crawl_url)
print("We can crawl Google Play? {0}".format(can_crawl_listings))
# Out:
# We can crawl Google Play? True

# %%
import pandas as pd
import matplotlib as mpl
import datetime as dt
df = pd.read_csv(r"C:\Users\gosharm\Downloads\TEST\Data Science\practical-pandas-projects_Gourav\datasets\google-play-store-11-2018.csv", index_col= "app_id")

# %%
#from datetime import date
#import datetime as dt
today = date.today()
df["Current Day"] = today
df["No_Of_Days"] = (pd.to_datetime(df["Current Day"]) - pd.to_datetime(df["released"])).dt.days
df.rename(columns={'rating_one_star': '1 Star', 'rating_two_star': '2 Star', 'rating_three_star': '3 Star', 'rating_four_star': '4 Star', 'rating_five_star': '5 Star'}, inplace=True)
df['Avg_download'] = round(df['min_installs']/df['No_Of_Days'])
#df.set_index("app_id", inplace=True)
df.columns = [x.title() for x in df.columns]
df.sort_index()
# Out:
#                                                                                   Title
# app_id
# AutomateIt.mainPackage                AutomateIt - Automate tasks, save battery and ...  \
# CP.iCarCheck                                                          Instant Car Check
# Com.sktelecom.minit                                                         모바일 T world
# DeadlyDungeons.App                                                      Deadly Dungeons
# Draziw.Button.Mines                                                         Minesweeper
# ...                                                                                 ...
# zvector.colorbynumbers.sandboxpixels                    Color by Number - Sandbox Pixel
# zw.co.champions.champ                                               Champions Insurance
# zw.co.ledger.ecocash                                                          EcoLedger
# zw.co.simbisa.dad                                                       Dial a Delivery
# zzz1zzz.tracktime                                               Time Tracker - Pomodoro
#
#                                       Reviews   Ratings  Min_Installs
# app_id
# AutomateIt.mainPackage                 5824.0   14680.0       1000000  \
# CP.iCarCheck                            641.0    1516.0        100000
# Com.sktelecom.minit                   16152.0   51237.0      10000000
# DeadlyDungeons.App                     1045.0    3206.0         50000
# Draziw.Button.Mines                   41384.0  182316.0       5000000
# ...                                       ...       ...           ...
# zvector.colorbynumbers.sandboxpixels    132.0     398.0         10000
# zw.co.champions.champ                     1.0       3.0           100
# zw.co.ledger.ecocash                    194.0     394.0         10000
# zw.co.simbisa.dad                         6.0      11.0           500
# zzz1zzz.tracktime                       294.0     479.0         50000
#
#                                          Score  Offers_Iap  Ad_Supported
# app_id
# AutomateIt.mainPackage                4.179155        True          True  \
# CP.iCarCheck                          3.785620        True         False
# Com.sktelecom.minit                   3.721159       False          True
# DeadlyDungeons.App                    4.272614       False         False
# Draziw.Button.Mines                   4.627729       False          True
# ...                                        ...         ...           ...
# zvector.colorbynumbers.sandboxpixels  4.522613       False          True
# zw.co.champions.champ                 5.000000       False         False
# zw.co.ledger.ecocash                  4.215736       False         False
# zw.co.simbisa.dad                     4.000000       False         False
# zzz1zzz.tracktime                     4.432150        True          True
#
#                                         Released  Ratings_Per_Day
# app_id
# AutomateIt.mainPackage                2011-02-04                5  \
# CP.iCarCheck                          2011-05-23                0
# Com.sktelecom.minit                   2010-08-10               16
# DeadlyDungeons.App                    2011-04-19                1
# Draziw.Button.Mines                   2012-07-10               78
# ...                                          ...              ...
# zvector.colorbynumbers.sandboxpixels  2018-09-08                5
# zw.co.champions.champ                 2018-08-08                0
# zw.co.ledger.ecocash                  2018-03-08                1
# zw.co.simbisa.dad                     2018-10-22                0
# zzz1zzz.tracktime                     2017-01-12                0
#
#                                              Genre           Genre_Id  Price
# app_id
# AutomateIt.mainPackage                Productivity       PRODUCTIVITY   0.00  \
# CP.iCarCheck                                 Tools              TOOLS   0.00
# Com.sktelecom.minit                      Lifestyle          LIFESTYLE   0.00
# DeadlyDungeons.App                    Role Playing  GAME_ROLE_PLAYING   0.99
# Draziw.Button.Mines                         Puzzle        GAME_PUZZLE   0.00
# ...                                            ...                ...    ...
# zvector.colorbynumbers.sandboxpixels        Comics             COMICS   0.00
# zw.co.champions.champ                     Business           BUSINESS   0.00
# zw.co.ledger.ecocash                       Finance            FINANCE   0.00
# zw.co.simbisa.dad                     Food & Drink     FOOD_AND_DRINK   0.00
# zzz1zzz.tracktime                     Productivity       PRODUCTIVITY   0.00
#
#                                       1 Star  2 Star  3 Star  4 Star  5 Star
# app_id
# AutomateIt.mainPackage                   982     695    1335    3367    8301  \
# CP.iCarCheck                             314      69     101     176     856
# Com.sktelecom.minit                    10059    2277    4971    8515   25415
# DeadlyDungeons.App                       116     123     340     819    1808
# Draziw.Button.Mines                     2578    1326    6955   39671  131786
# ...                                      ...     ...     ...     ...     ...
# zvector.colorbynumbers.sandboxpixels      12       7      36      49     294
# zw.co.champions.champ                      0       0       0       0       3
# zw.co.ledger.ecocash                      31      12      43      63     245
# zw.co.simbisa.dad                          2       0       1       1       7
# zzz1zzz.tracktime                         19      10      42      82     326
#
#                                      Current Day  No_Of_Days  Avg_Download
# app_id
# AutomateIt.mainPackage                2023-08-29      4589.0         218.0
# CP.iCarCheck                          2023-08-29      4481.0          22.0
# Com.sktelecom.minit                   2023-08-29      4767.0        2098.0
# DeadlyDungeons.App                    2023-08-29      4515.0          11.0
# Draziw.Button.Mines                   2023-08-29      4067.0        1229.0
# ...                                          ...         ...           ...
# zvector.colorbynumbers.sandboxpixels  2023-08-29      1816.0           6.0
# zw.co.champions.champ                 2023-08-29      1847.0           0.0
# zw.co.ledger.ecocash                  2023-08-29      2000.0           5.0
# zw.co.simbisa.dad                     2023-08-29      1772.0           0.0
# zzz1zzz.tracktime                     2023-08-29      2420.0          21.0
#
# [62694 rows x 20 columns]

# %% [markdown]
# Groupby Installs by Genre

# %%
Max_Download_Genre = df.groupby("Genre")
Max_Download_Genre["Min_Installs"].value_counts()
# Out:
# Genre   Min_Installs
# Action  1000000         268
#         100000          180
#         10000000        132
#         500000           98
#         5000000          90
#                        ...
# Word    10000000         20
#         5000000          19
#         50000            10
#         50000000          4
#         5000              3
# Name: count, Length: 706, dtype: int64

# %% [markdown]
# Groupbt Installs by Genre (Percentage)

# %%
Max_Download_Genre = df.groupby("Genre")
Max_Download_Genre["Min_Installs"].value_counts(normalize=True)
# Out:
# Genre   Min_Installs
# Action  1000000         0.275154
#         100000          0.184805
#         10000000        0.135524
#         500000          0.100616
#         5000000         0.092402
#                           ...
# Word    10000000        0.101010
#         5000000         0.095960
#         50000           0.050505
#         50000000        0.020202
#         5000            0.015152
# Name: proportion, Length: 706, dtype: float64

# %%
Med = Max_Download_Genre["Min_Installs"].median().sort_values(ascending = False)
# Out:
# Genre
# Action                     1000000.0
# Racing                     1000000.0
# Casual                     1000000.0
# Casino                      500000.0
# Strategy                    500000.0
# Simulation                  500000.0
# Role Playing                500000.0
# Word                        500000.0
# Arcade                      500000.0
# Educational                 100000.0
# Puzzle                      100000.0
# Music                       100000.0
# Card                        100000.0
# Social                      100000.0
# Photography                 100000.0
# Tools                       100000.0
# Adventure                   100000.0
# Dating                      100000.0
# Trivia                      100000.0
# Video Players & Editors     100000.0
# Board                       100000.0
# Weather                     100000.0
# Productivity                 50000.0
# Parenting                    50000.0
# Sports                       50000.0
# Personalization              50000.0
# Shopping                     50000.0
# Entertainment                50000.0
# Travel & Local               50000.0
# Beauty                       10000.0
# Art & Design                 10000.0
# Music & Audio                10000.0
# Lifestyle                    10000.0
# News & Magazines             10000.0
# Maps & Navigation            10000.0
# Libraries & Demo             10000.0
# Health & Fitness             10000.0
# Finance                      10000.0
# Communication                10000.0
# Comics                       10000.0
# Books & Reference            10000.0
# Auto & Vehicles               5000.0
# House & Home                  5000.0
# Education                     5000.0
# Medical                       1000.0
# Food & Drink                  1000.0
# Events                        1000.0
# Business                      1000.0
# Name: Min_Installs, dtype: float64
